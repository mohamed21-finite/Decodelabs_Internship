# %% [markdown]
# # Task1 Data Collection & Dataset understanding

# %%
import pandas as pd

# %%
df = pd.read_csv('Co2_Emissions_by_Sectors.csv')

# %% [markdown]
# ## get the size of the dataset

# %%
df.shape
# Out:
# (17686, 16)

# %% [markdown]
# ## get the columns' names

# %%
df.columns
# Out:
# Index(['Industry_Type', 'Region', 'Country', 'Year',
#        'Co2_Emissions_MetricTons', 'Energy_Consumption_TWh',
#        'Automobile_Co2_Emissions_MetricTons',
#        'Industrial_Co2_Emissions_MetricTons',
#        'Agriculture_Co2_Emissions_MetricTons',
#        'Domestic_Co2_Emissions_MetricTons', 'Population_Millions',
#        'GDP_Billion_USD', 'Urbanization_Percentage',
#        'Renewable_Energy_Percentage', 'Industrial_Growth_Percentage',
#        'Transport_Growth_Percentage'],
#       dtype='str')

# %% [markdown]
# ## get the datatypes and how many nulls in the data

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17686 entries, 0 to 17685
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Industry_Type                         17686 non-null  str
#  1   Region                                17686 non-null  str
#  2   Country                               17686 non-null  str
#  3   Year                                  17686 non-null  int64
#  4   Co2_Emissions_MetricTons              17686 non-null  float64
#  5   Energy_Consumption_TWh                17686 non-null  float64
#  6   Automobile_Co2_Emissions_MetricTons   17686 non-null  float64
#  7   Industrial_Co2_Emissions_MetricTons   17686 non-null  float64
#  8   Agriculture_Co2_Emissions_MetricTons  17686 non-null  float64
#  9   Domestic_Co2_Emissions_MetricTons     17686 non-null  float64
#  10  Population_Millions                   17686 non-null  float64
# ...

# %% [markdown]
# ## Exploring the first five records and the basic statistics

# %%
df.head()
# Out:
#    Industry_Type         Region       Country  Year  Co2_Emissions_MetricTons  \
# 0   Construction  North America        Brazil  2010                     89.13
# 1         Mining         Europe       Germany  2006                    224.81
# 2  Manufacturing  South America  South Africa  2017                    179.72
# 3   Construction         Europe         India  2018                     23.28
# 4   Construction         Africa         China  2013                    124.54
#
#    Energy_Consumption_TWh  Automobile_Co2_Emissions_MetricTons  \
# 0                   90.14                                98.37
# 1                  931.70                                10.81
# 2                  255.14                                55.36
# 3                  887.29                                78.99
# 4                  923.03                                65.93
#
#    Industrial_Co2_Emissions_MetricTons  Agriculture_Co2_Emissions_MetricTons  \
# ...

# %% [markdown]
# ## Task2 Cleaning the data

# %% [markdown]
# ## the region Column wasn't right i'm going to assign the right continent with the right country

# %%
countries =df['Country'].unique().tolist()
countries
# Out:
# ['Brazil',
#  'Germany',
#  'South Africa',
#  'India',
#  'China',
#  'Australia',
#  'Canada',
#  'USA']

# %%
regions = df['Region'].unique().tolist()
regions
# Out:
# ['North America', 'Europe', 'South America', 'Africa', 'Asia', 'Oceania']

# %%
country_to_continent = {
    'Brazil': 'South America',
    'Germany': 'Europe',
    'South Africa': 'Africa',
    'India': 'Asia',
    'China': 'Asia',
    'Australia': 'Asia',
    'Canada': 'North America',
    'USA': 'North America',
    # ... add all countries from your list
}

# %%
df['Region'] = df['Country'].map(country_to_continent)

# %%
df.head()
# Out:
#    Industry_Type         Region       Country  Year  Co2_Emissions_MetricTons  \
# 0   Construction  South America        Brazil  2010                     89.13
# 1         Mining         Europe       Germany  2006                    224.81
# 2  Manufacturing         Africa  South Africa  2017                    179.72
# 3   Construction           Asia         India  2018                     23.28
# 4   Construction           Asia         China  2013                    124.54
#
#    Energy_Consumption_TWh  Automobile_Co2_Emissions_MetricTons  \
# 0                   90.14                                98.37
# 1                  931.70                                10.81
# 2                  255.14                                55.36
# 3                  887.29                                78.99
# 4                  923.03                                65.93
#
#    Industrial_Co2_Emissions_MetricTons  Agriculture_Co2_Emissions_MetricTons  \
# ...

# %% [markdown]
# # Task3 EDA

# %%
df1 = df.copy()

# %%
df1.describe()
# Out:
#                Year  Co2_Emissions_MetricTons  Energy_Consumption_TWh  \
# count  17686.000000              17686.000000            17686.000000
# mean    2011.024935                150.331667              500.071501
# std        6.657483                 86.401588              287.008603
# min     2000.000000                  0.500000                0.630000
# 25%     2005.000000                 75.580000              252.447500
# 50%     2011.000000                150.820000              499.645000
# 75%     2017.000000                225.247500              750.065000
# max     2022.000000                299.990000              999.880000
#
#        Automobile_Co2_Emissions_MetricTons  \
# count                         17686.000000
# mean                             49.983267
# std                              28.936346
# min                               0.110000
# 25%                              24.712500
# 50%                              50.305000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                           Year  Co2_Emissions_MetricTons  \
# Year                                  1.000000                  0.003300
# Co2_Emissions_MetricTons              0.003300                  1.000000
# Energy_Consumption_TWh                0.003778                  0.011754
# Automobile_Co2_Emissions_MetricTons   0.008897                 -0.009433
# Industrial_Co2_Emissions_MetricTons   0.002683                  0.006888
# Agriculture_Co2_Emissions_MetricTons -0.005286                 -0.008660
# Domestic_Co2_Emissions_MetricTons     0.001692                  0.013756
# Population_Millions                   0.001951                  0.013694
# GDP_Billion_USD                      -0.006494                  0.006703
# Urbanization_Percentage              -0.010045                 -0.008156
# Renewable_Energy_Percentage          -0.001296                  0.000248
# Industrial_Growth_Percentage         -0.003961                  0.007791
# ...

# %%
emission_by_years = df1.groupby('Year')['Co2_Emissions_MetricTons'].sum().reset_index()
maximum_5_emission_by_years = emission_by_years.nlargest(5, 'Co2_Emissions_MetricTons')
maximum_5_emission_by_years
# Out:
#     Year  Co2_Emissions_MetricTons
# 9   2009                 124039.96
# 22  2022                 123583.00
# 21  2021                 120348.95
# 18  2018                 118951.81
# 6   2006                 118892.94

# %%
emission_by_sectors = df1.groupby('Industry_Type')['Co2_Emissions_MetricTons'].sum().reset_index()
maximum_5_emission_by_sectors = emission_by_sectors.nlargest(5, 'Co2_Emissions_MetricTons')
maximum_5_emission_by_sectors
# Out:
#    Industry_Type  Co2_Emissions_MetricTons
# 2  Manufacturing                 681318.39
# 0   Construction                 666185.79
# 1         Energy                 658166.85
# 3         Mining                 653094.83

# %%
emission_by_regions = df1.groupby('Region')['Co2_Emissions_MetricTons'].sum().reset_index()
emission_by_regions.sort_values(by='Co2_Emissions_MetricTons', ascending=False).head(5)
# Out:
#           Region  Co2_Emissions_MetricTons
# 1           Asia                 992059.60
# 3  North America                 657201.31
# 4  South America                 352987.33
# 2         Europe                 336583.64
# 0         Africa                 319933.98

# %% [markdown]
# # Task4 Data Visualization

# %%
import matplotlib.pyplot as plt

plt.figure()

emission_by_countries = df1.groupby('Country')['Co2_Emissions_MetricTons'].sum().reset_index()

plt.bar(emission_by_countries['Country'], emission_by_countries['Co2_Emissions_MetricTons'])

plt.xlabel('Country')
plt.ylabel('CO2 Emissions (Metric Tons)')
plt.title('CO2 Emissions by Country')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure()
emission_by_sectors = df1.groupby('Industry_Type')['Co2_Emissions_MetricTons'].sum().reset_index()
plt.bar(emission_by_sectors['Industry_Type'], emission_by_sectors['Co2_Emissions_MetricTons'])
plt.xlabel('Industry Type')
plt.ylabel('CO2 Emissions (Metric Tons)')
plt.title('CO2 Emissions by Industry Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure()
emission_by_regions = df1.groupby('Region')['Co2_Emissions_MetricTons'].sum().reset_index()
plt.bar(emission_by_regions['Region'], emission_by_regions['Co2_Emissions_MetricTons'])
plt.xlabel('Region')
plt.ylabel('CO2 Emissions (Metric Tons)')
plt.title('CO2 Emissions by Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure()
emission_by_years = df1.groupby('Year')['Co2_Emissions_MetricTons'].sum().reset_index()
plt.plot(emission_by_years['Year'], emission_by_years['Co2_Emissions_MetricTons'], marker='o')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (Metric Tons)')
plt.title('CO2 Emissions by Year')
plt.tight_layout()
plt.show()

# %%
plt.figure()
plt.boxplot(df1['Co2_Emissions_MetricTons'])
plt.title('Box Plot of CO2 Emissions (Metric Tons)')    
plt.ylabel('CO2 Emissions (Metric Tons)')
plt.tight_layout()
plt.show()

# %%
plt.figure()
plt.hist(df1['Co2_Emissions_MetricTons'], bins=40, edgecolor='black')
plt.xlabel('CO2 Emissions (Metric Tons)')
plt.ylabel('Frequency')
plt.title('Histogram of CO2 Emissions (Metric Tons)')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(15,10))
sns.heatmap(df1.corr(numeric_only=True), annot=True, cmap='Reds')
plt.show()
